# %%
import numpy as np

data = np.array([
[78, 85, 90, 92],
[45, 50, 40, 75],
[88, 92, 85, 96],
[60, 65, 70, 80],
[95, 98, 94, 99],
[30, 40, 35, 60],
[72, 75, 70, 85],
[85, 80, 88, 90],
[55, 58, 60, 78],
[91, 89, 93, 97]
])

print(np.sum(data[:,:3],axis=1))
# Out:
# [253 135 265 195 287 105 217 253 173 273]
