# %% [markdown]
# ### Pie Chart

# %%
import matplotlib.pyplot as plt

sales=[300,200,600]  #()

plt.pie(sales)

plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [40, 30, 20, 10]
labels = ['Rent', 'Food', 'Travel', 'Savings']

explode = (0.1, 0.1, 0.1,0.1)
# explode = (0.1, 0, 0, 0)
color=["r","b","y","g"]

# plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=90,explode=explode,shadow=True)
# plt.pie(sizes,labels=labels,autopct='%1.1f%%',colors=color,wedgeprops={"linewidth":4,"edgecolor":"g"},explode=explode)
# plt.pie(sizes,labels=labels,autopct='%1.1f%%',radius=1,colors=color,labeldistance=1.2,counterclock=True)
plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=45,textprops={"fontsize":14},labeldistance=1.2)
# plt.pie(sizes,labels=labels,autopct='%1.1f%%',shadow=True,counterclock=False,wedgeprops={"linewidth":14,"edgecolor":"m"})
# plt.pie(sizes,labels=labels,autopct='%1.1f%%',rotatelabels=True,colors=color,startangle=180,explode=explode,shadow=True)
# plt.pie(sizes,labels=labels,autopct='%1.1f%%',colors=color)
# plt.pie(sizes,labels=labels,colors=color)
# plt.pie(sizes)

plt.title("Monthly Expense Distribution")
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ### Pie Chart With Single Value (Dot Chart)

# %%
plt.pie([1])
plt.show()

# %% [markdown]
# ### MultiPie Charts

# %%
import matplotlib.pyplot as plt

sizes1 = [40, 30, 20, 10] 
# sizes2 = [34, 67, 26, 78] 

sizes3 = [1]

labels = ['Rent', 'Food', 'Travel', 'Savings']

color=["r","b","y","g"]

# plt.pie(sizes3)

plt.pie(sizes1,labels=labels,autopct='%1.1f%%',radius=1.2)
plt.pie(sizes3,radius=0.58,colors="w")
# plt.pie(sizes2,autopct='%1.1f%%',radius=0.5)

plt.title("Monthly Expense Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

sizes1 = [40, 30, 20, 10] 
sizes2 = [1] 
labels = ['Rent', 'Food', 'Travel', 'Savings']
color=["r","b","y","g"]

plt.pie(sizes1,labels=labels,autopct='%1.1f%%',radius=1)
plt.pie(sizes2,radius=0.4,colors="w")

plt.title("Monthly Expense Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

sizes1 = [40, 30, 20, 10] 
labels = ['Rent', 'Food', 'Travel', 'Savings']
color=["r","b","y","g"]


plt.pie(sizes1,labels=labels,autopct='%1.1f%%',radius=1)

cr=plt.Circle(xy=(0,0),radius=0.8,facecolor="y")

plt.gca().add_artist(cr)

plt.title("Monthly Expense Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [40, 30, 20, 10]
labels = ['A', 'B', 'C', 'D']
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    wedgeprops={'width': 0.8}
)
plt.show()

# %% [markdown]
# ### Stem Chart

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.stem(x, y,linefmt='--',markerfmt='o',basefmt='k-',orientation="horizontal")

# plt.stem(x, y,linefmt=":",markerfmt="r+",basefmt='k-')

# plt.stem(x, y,linefmt="--",markerfmt="g*",basefmt="g-")

plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Stem Plot Example")
plt.show()

# %% [markdown]
# ### Box Plotting

# %%
import matplotlib.pyplot as plt

data= [10,20,30,40,50,60,70,120]
# data = [10, 20, 25, 30, 35, 40,80]
# data = [10, 20, 25, 30, 35, 40]

# plt.boxplot(data)
# plt.boxplot(data,notch=True)
# plt.boxplot(data,vert=False)
# plt.boxplot(data,widths=0.1) 

# plt.boxplot(data,label=["Data"])
# plt.boxplot(data,patch_artist=True)
# plt.boxplot(data,patch_artist=True,showmeans=True)
# plt.boxplot(data,patch_artist=True,showmeans=True,sym="rD",whis=3)
# plt.boxplot(data,patch_artist=True,showmeans=True,sym="go",whis=3)

plt.boxplot(data,patch_artist=True,showmeans=True,boxprops=dict(facecolor='lightgreen',color="red"),medianprops=dict(color='blue'))
# plt.boxplot(data,patch_artist=True,showmeans=True,capprops=dict(color="b"),whiskerprops=dict(color="g"))

# plt.boxplot(data)

plt.title("Box Plot Example")
plt.ylabel("Values")
# plt.legend()
plt.show()

# %% [markdown]
# ### MultiBox Plotting

# %%
import matplotlib.pyplot as plt

data1 = [10, 20, 25, 30, 35, 40]
data2=[30,56,45,10,89,34]
data3=[20,96,65,10,89,34]

y=[data1,data2,data3]

plt.boxplot(y,label=["Python","Java","Node.js"],patch_artist=True,showmeans=True,capprops=dict(color="b"),whiskerprops=dict(color="g"))

plt.title("Box Plot Example")
plt.ylabel("Values")
plt.xlabel("<-- Languages -->")
plt.show()
