# %%
import pandas as pd

data1=pd.DataFrame({"a":[3,5,8],"b":[2,7,3],"c":[4,7,6]})

data1

data1.to_csv("hifzur2.csv",index=False,header=["A","B","C"])

# %%
# import numpy as np

# var1 = [[1,2,3,4,5],
#         [3,5,2,7,8],
#         [3,1,1,7,8],
#         [3,2,7,7,2]
#         ]
# arr1=np.array(var1)
# print(arr1[0:2,:4])

# %%
import pandas as pd

var1=pd.Series([4,7,3,2])
print(var1)
print(type(var1))
# Out:
# 0    4
# 1    7
# 2    3
# 3    2
# dtype: int64
# <class 'pandas.Series'>

# %%
var2=pd.Series({"Roll Num.":[101,102,103,104],"Marks":[34,67,75,99]})
print(var2)
print(type(var2))
# Out:
# Roll Num.    [101, 102, 103, 104]
# Marks            [34, 67, 75, 99]
# dtype: object
# <class 'pandas.Series'>
