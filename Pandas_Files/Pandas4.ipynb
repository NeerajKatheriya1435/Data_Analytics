# %%
import pandas as pd

data1=pd.read_csv("newtest.csv")
data1
# Out:
#     S.N.               Name  Contact No.  Year             Address
# 0      1     Mohit Tripathi   8887331179   2nd           Prayagraj
# 1      2        Jay Narayan   9511493970   3rd           Sultanpur
# 2      3           Aman Pal   9151503447   2nd             Jaunpur
# 3      4         Nikhil Rai   9305080327   2nd  Maunath Bhajan Mau
# 4      5       Sonush Kumar   8400716124   2nd          Shajahapur
# 5      6        Vivek Kumar   9151480914   3rd           Sonbhadra
# 6      7      Pranshu Dubey   8707037056   2nd            Mirzapur
# 7      8       Vishal Kumar   8273730104   3rd            Bareilly
# 8      9       Sujeet Kumar   9565256344   2nd              Ballia
# 9     10        Niraj Kumar   7310362981   NaN              Ballia
# 10    11        Mohit Yadav   9721334026   2nd      Ambedkar Nagar
# 11    12   Himanshu Katiyar   9897515619   2nd            Bareilly
# 12    13       Mayank Singh   8960959096   NaN         RaeBareilly
# ...

# %%
data1.replace(to_replace="2nd",value="4rth")
# data1.replace("2nd","4rth")
# Out:
#     S.N.               Name  Contact No.  Year             Address
# 0      1     Mohit Tripathi   8887331179  4rth           Prayagraj
# 1      2        Jay Narayan   9511493970   3rd           Sultanpur
# 2      3           Aman Pal   9151503447  4rth             Jaunpur
# 3      4         Nikhil Rai   9305080327  4rth  Maunath Bhajan Mau
# 4      5       Sonush Kumar   8400716124  4rth          Shajahapur
# 5      6        Vivek Kumar   9151480914   3rd           Sonbhadra
# 6      7      Pranshu Dubey   8707037056  4rth            Mirzapur
# 7      8       Vishal Kumar   8273730104   3rd            Bareilly
# 8      9       Sujeet Kumar   9565256344  4rth              Ballia
# 9     10        Niraj Kumar   7310362981   NaN              Ballia
# 10    11        Mohit Yadav   9721334026  4rth      Ambedkar Nagar
# 11    12   Himanshu Katiyar   9897515619  4rth            Bareilly
# 12    13       Mayank Singh   8960959096   NaN         RaeBareilly
# ...

# %%
# import openpyxl


data1.replace([1,2,3,4,5,6,7,9,22],455)
# df = pd.read_csv(data1)
    
    # Step 2: Write the DataFrame to an Excel file
    # index=False ensures the row numbers aren't written as a column
# data1.to_excel("Rohan123.xlsx", index=False, sheet_name='Data')

# data1.replace([1,2,3,4,5,6,7,9,22],455)

# data1.to_csv("Rohan.xlsx",index=False)
# data1.to_excel("Rohan123.xlsx")
# data1.replace("2nd",5)
# Out:
#     S.N.               Name  Contact No.  Year             Address
# 0    455     Mohit Tripathi   8887331179   2nd           Prayagraj
# 1    455        Jay Narayan   9511493970   3rd           Sultanpur
# 2    455           Aman Pal   9151503447   2nd             Jaunpur
# 3    455         Nikhil Rai   9305080327   2nd  Maunath Bhajan Mau
# 4    455       Sonush Kumar   8400716124   2nd          Shajahapur
# 5    455        Vivek Kumar   9151480914   3rd           Sonbhadra
# 6    455      Pranshu Dubey   8707037056   2nd            Mirzapur
# 7      8       Vishal Kumar   8273730104   3rd            Bareilly
# 8    455       Sujeet Kumar   9565256344   2nd              Ballia
# 9     10        Niraj Kumar   7310362981   NaN              Ballia
# 10    11        Mohit Yadav   9721334026   2nd      Ambedkar Nagar
# 11    12   Himanshu Katiyar   9897515619   2nd            Bareilly
# 12    13       Mayank Singh   8960959096   NaN         RaeBareilly
# ...

# %%
# data1.replace("[A-Za-z]","Python",regex=True)
# data1.replace("[A-F]","panda",regex=True)
# data1.replace("[A-Fa-z]","panda",regex=True)
# data1.replace("[0-9]","panda",regex=True)

# %%
data1.replace({"Year":"2nd"},56,regex=True)
# Out:
#     S.N.               Name  Contact No.  Year             Address
# 0      1     Mohit Tripathi   8887331179    56           Prayagraj
# 1      2        Jay Narayan   9511493970   3rd           Sultanpur
# 2      3           Aman Pal   9151503447    56             Jaunpur
# 3      4         Nikhil Rai   9305080327    56  Maunath Bhajan Mau
# 4      5       Sonush Kumar   8400716124    56          Shajahapur
# 5      6        Vivek Kumar   9151480914   3rd           Sonbhadra
# 6      7      Pranshu Dubey   8707037056    56            Mirzapur
# 7      8       Vishal Kumar   8273730104   3rd            Bareilly
# 8      9       Sujeet Kumar   9565256344    56              Ballia
# 9     10        Niraj Kumar   7310362981   NaN              Ballia
# 10    11        Mohit Yadav   9721334026    56      Ambedkar Nagar
# 11    12   Himanshu Katiyar   9897515619    56            Bareilly
# 12    13       Mayank Singh   8960959096   NaN         RaeBareilly
# ...

# %%
import pandas as pd

data1=pd.read_csv("newtest2.csv")
data1
# Out:
#        1    8887331179  Unnamed: 2
# 0    2.0  9.511494e+09      3000.0
# 1    3.0  9.151503e+09      4000.0
# 2    4.0  9.305080e+09      5000.0
# 3    5.0  8.400716e+09      6000.0
# 4    6.0  9.151481e+09      7000.0
# 5    7.0  8.707037e+09         NaN
# 6    8.0  8.273730e+09         NaN
# 7    9.0  9.565256e+09      3000.0
# 8   10.0  7.310363e+09      4000.0
# 9   11.0           NaN      5000.0
# 10  12.0           NaN         NaN
# 11  13.0           NaN         NaN
# 12   NaN           NaN         NaN
# 13   NaN           NaN         NaN
# 14   NaN           NaN         NaN
# 15   NaN           NaN         NaN
# 16   NaN           NaN         NaN
# 17  19.0  8.267968e+09         NaN
# 18  20.0  7.317762e+09         NaN
# 19  21.0  7.398558e+09         NaN
# 20  22.0  8.115515e+09         NaN
# 21  23.0  8.115192e+09      2000.0
# 22  24.0  8.409108e+09      3000.0
# 23  25.0  9.795591e+09      4000.0
# 24  26.0  8.601098e+09      5000.0
# 25  27.0  7.817895e+09      6000.0
# ...

# %%
# to interpolate the missing values

# data1.interpolate(method ='linear', limit_direction ='forward')

# data1.interpolate()
# data1.interpolate(method="index",axis=0)
# data1.interpolate(method="index",limit=7,limit_direction ='backward')
data1
# Out:
#        1    8887331179  Unnamed: 2
# 0    2.0  9.511494e+09      3000.0
# 1    3.0  9.151503e+09      4000.0
# 2    4.0  9.305080e+09      5000.0
# 3    5.0  8.400716e+09      6000.0
# 4    6.0  9.151481e+09      7000.0
# 5    7.0  8.707037e+09         NaN
# 6    8.0  8.273730e+09         NaN
# 7    9.0  9.565256e+09      3000.0
# 8   10.0  7.310363e+09      4000.0
# 9   11.0           NaN      5000.0
# 10  12.0           NaN         NaN
# 11  13.0           NaN         NaN
# 12   NaN           NaN         NaN
# 13   NaN           NaN         NaN
# 14   NaN           NaN         NaN
# 15   NaN           NaN         NaN
# 16   NaN           NaN         NaN
# 17  19.0  8.267968e+09         NaN
# 18  20.0  7.317762e+09         NaN
# 19  21.0  7.398558e+09         NaN
# 20  22.0  8.115515e+09         NaN
# 21  23.0  8.115192e+09      2000.0
# 22  24.0  8.409108e+09      3000.0
# 23  25.0  9.795591e+09      4000.0
# 24  26.0  8.601098e+09      5000.0
# 25  27.0  7.817895e+09      6000.0
# ...

# %%
import pandas as pd

data1=pd.read_csv("newtest2.csv")

data1
# data1.interpolate(method="index",limit=6,limit_direction="backward",axis=1)
# data1.interpolate(method="index",limit=2,limit_direction="both")
# data1.interpolate(limit_area="inside")

data1.interpolate(limit_area="outside")

# data1
# Out:
#        1    8887331179  Unnamed: 2
# 0    2.0  9.511494e+09      3000.0
# 1    3.0  9.151503e+09      4000.0
# 2    4.0  9.305080e+09      5000.0
# 3    5.0  8.400716e+09      6000.0
# 4    6.0  9.151481e+09      7000.0
# 5    7.0  8.707037e+09         NaN
# 6    8.0  8.273730e+09         NaN
# 7    9.0  9.565256e+09      3000.0
# 8   10.0  7.310363e+09      4000.0
# 9   11.0           NaN      5000.0
# 10  12.0           NaN         NaN
# 11  13.0           NaN         NaN
# 12   NaN           NaN         NaN
# 13   NaN           NaN         NaN
# 14   NaN           NaN         NaN
# 15   NaN           NaN         NaN
# 16   NaN           NaN         NaN
# 17  19.0  8.267968e+09         NaN
# 18  20.0  7.317762e+09         NaN
# 19  21.0  7.398558e+09         NaN
# 20  22.0  8.115515e+09         NaN
# 21  23.0  8.115192e+09      2000.0
# 22  24.0  8.409108e+09      3000.0
# 23  25.0  9.795591e+09      4000.0
# 24  26.0  8.601098e+09      5000.0
# 25  27.0  7.817895e+09      6000.0
# ...
